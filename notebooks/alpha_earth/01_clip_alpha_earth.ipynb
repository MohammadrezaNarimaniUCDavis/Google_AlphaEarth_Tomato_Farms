# %% [markdown]
# # Local Alpha Earth clips — index
#
# Year-specific notebooks (tomato GPKG + local GeoTIFF) live under **[`years/`](years/README.md)**.
#
# | Survey year | Notebook |
# |-------------|----------|
# | **2018** | [`years/2018/01_clip_local_alphaearth_2018_tomato.ipynb`](years/2018/01_clip_local_alphaearth_2018_tomato.ipynb) |
#
# **Earth Engine** pilots: [`earth_engine/years/README.md`](earth_engine/years/README.md).
#
# Raster layout: `alpha_earth.local_raster_root` in YAML (default `data/derived/alpha_earth_rasters`) with a **`2018/`** (or other year) subfolder containing your `.tif`.
